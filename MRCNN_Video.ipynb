# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir('./gdrive/My Drive/Mask_RCNN')

# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt

ROOT_DIR = os.path.abspath("Desktop/Mask_RCNN")
import warnings
warnings.filterwarnings("ignore")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
# Import COCO config
#sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
import cv2
import numpy as np


def random_colors(N):
    np.random.seed(1)
    colors = [tuple(255 * np.random.rand(3)) for _ in range(N)]
    return colors


def apply_mask(image, mask, color, alpha=0.5):
    """apply mask to image"""
    for n, c in enumerate(color):
        image[:, :, n] = np.where(
            mask == 1,
            image[:, :, n] * (1 - alpha) + alpha * c,
            image[:, :, n]
        )
    return image

def display_instances(image, boxes, masks, ids, names, scores):
    """
        take the image and results and apply the mask, box, and Label
    """
    n_instances = boxes.shape[0]
    colors = random_colors(n_instances)

    if not n_instances:
        print('NO INSTANCES TO DISPLAY')
    else:
        assert boxes.shape[0] == masks.shape[-1] == ids.shape[0]

    for i, color in enumerate(colors):
        if not np.any(boxes[i]):
            continue

        y1, x1, y2, x2 = boxes[i]
        label = names[ids[i]]
        score = scores[i] if scores is not None else None
        caption = '{} {:.2f}'.format(label, score) if score else label
        mask = masks[:, :, i]

        image = apply_mask(image, mask, color)
        image = cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        image = cv2.putText(
            image, caption, (x1, y1), cv2.FONT_HERSHEY_COMPLEX, 0.7, color, 2
        )

    return image

if __name__ == '__main__':
    """
        test everything
    """
    import os
    import sys
    from mrcnn import utils
    import mrcnn.model as modellib
    #sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
    from samples.coco import coco
    
    # We use a K80 GPU with 24GB memory, which can fit 3 images.
    batch_size = 3

    ROOT_DIR = os.getcwd()
    MODEL_DIR = os.path.join(ROOT_DIR, "logs")
    VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
    VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "save")
    COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
    if not os.path.exists(COCO_MODEL_PATH):
        utils.download_trained_weights(COCO_MODEL_PATH)
        
    class InferenceConfig(coco.CocoConfig):
        GPU_COUNT = 1
        IMAGES_PER_GPU = batch_size

    config = InferenceConfig()
    config.display()

    model = modellib.MaskRCNN(
        mode="inference", model_dir=MODEL_DIR, config=config
    )
    model.load_weights(COCO_MODEL_PATH, by_name=True)
    class_names = [
        'BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
        'bus', 'train', 'truck', 'boat', 'traffic light',
        'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
        'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
        'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
        'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
        'kite', 'baseball bat', 'baseball glove', 'skateboard',
        'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
        'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
        'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
        'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
        'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
        'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
        'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
        'teddy bear', 'hair drier', 'toothbrush'
    ]
    
    capture = cv2.VideoCapture(os.path.join(VIDEO_DIR, 'data.mp4'))
    try:
        if not os.path.exists(VIDEO_SAVE_DIR):
            os.makedirs(VIDEO_SAVE_DIR)
    except OSError:
        print ('Error: Creating directory of data')
    frames = []
    frame_count = 0
    # these 2 lines can be removed if you dont have a 1080p camera.
    #capture.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
    #capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)

    while True:
        ret, frame = capture.read()
        # Bail out when the video file ends
        if not ret:
            break
        
        # Save each frame of the video to a list
        frame_count += 1
        frames.append(frame)
        print('frame_count :{0}'.format(frame_count))
        if len(frames) == batch_size:
            results = model.detect(frames, verbose=0)
            print('Predicted')
            for i, item in enumerate(zip(frames, results)):
                frame = item[0]
                r = item[1]
                frame = display_instances(
                    frame, r['rois'], r['masks'], r['class_ids'], class_names, r['scores']
                )
                name = '{0}.jpg'.format(frame_count + i - batch_size)
                name = os.path.join(VIDEO_SAVE_DIR, name)
                cv2.imwrite(name, frame)
                print('writing to file:{0}'.format(name))
            # Clear the frames array to start the next batch
            frames = []

    capture.release()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     3
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 3
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001
#
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2139: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Mask_RCNN/mrcnn/model.py:341: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Mask_RCNN/mrcnn/model.py:399: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/gdrive/My Drive/Mask_RCNN/mrcnn/model.py:423: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /content/gdrive/My Drive/Mask_RCNN/mrcnn/model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Mask_RCNN/mrcnn/model.py:722: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Mask_RCNN/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# frame_count :1
# frame_count :2
# frame_count :3
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/0.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/1.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/2.jpg
# frame_count :4
# frame_count :5
# frame_count :6
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/4.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/5.jpg
# frame_count :7
# frame_count :8
# frame_count :9
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/6.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/7.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/8.jpg
# frame_count :10
# frame_count :11
# frame_count :12
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/9.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/10.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/11.jpg
# frame_count :13
# frame_count :14
# frame_count :15
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/12.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/13.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/14.jpg
# frame_count :16
# frame_count :17
# frame_count :18
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/15.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/16.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/17.jpg
# frame_count :19
# frame_count :20
# frame_count :21
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/18.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/19.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/20.jpg
# frame_count :22
# frame_count :23
# frame_count :24
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/21.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/22.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/23.jpg
# frame_count :25
# frame_count :26
# frame_count :27
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/24.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/25.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/26.jpg
# frame_count :28
# frame_count :29
# frame_count :30
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/27.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/28.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/29.jpg
# frame_count :31
# frame_count :32
# frame_count :33
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/30.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/31.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/32.jpg
# frame_count :34
# frame_count :35
# frame_count :36
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/33.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/34.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/35.jpg
# frame_count :37
# frame_count :38
# frame_count :39
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/36.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/37.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/38.jpg
# frame_count :40
# frame_count :41
# frame_count :42
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/39.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/40.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/41.jpg
# frame_count :43
# frame_count :44
# frame_count :45
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/42.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/43.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/44.jpg
# frame_count :46
# frame_count :47
# frame_count :48
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/45.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/46.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/47.jpg
# frame_count :49
# frame_count :50
# frame_count :51
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/48.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/49.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/50.jpg
# frame_count :52
# frame_count :53
# frame_count :54
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/51.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/52.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/53.jpg
# frame_count :55
# frame_count :56
# frame_count :57
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/54.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/55.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/56.jpg
# frame_count :58
# frame_count :59
# frame_count :60
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/57.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/58.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/59.jpg
# frame_count :61
# frame_count :62
# frame_count :63
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/60.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/61.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/62.jpg
# frame_count :64
# frame_count :65
# frame_count :66
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/63.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/64.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/65.jpg
# frame_count :67
# frame_count :68
# frame_count :69
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/66.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/67.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/68.jpg
# frame_count :70
# frame_count :71
# frame_count :72
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/69.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/70.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/71.jpg
# frame_count :73
# frame_count :74
# frame_count :75
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/72.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/73.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/74.jpg
# frame_count :76
# frame_count :77
# frame_count :78
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/75.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/76.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/77.jpg
# frame_count :79
# frame_count :80
# frame_count :81
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/78.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/79.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/80.jpg
# frame_count :82
# frame_count :83
# frame_count :84
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/81.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/82.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/83.jpg
# frame_count :85
# frame_count :86
# frame_count :87
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/84.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/85.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/86.jpg
# frame_count :88
# frame_count :89
# frame_count :90
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/87.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/88.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/89.jpg
# frame_count :91
# frame_count :92
# frame_count :93
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/90.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/91.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/92.jpg
# frame_count :94
# frame_count :95
# frame_count :96
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/93.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/94.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/95.jpg
# frame_count :97
# frame_count :98
# frame_count :99
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/96.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/97.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/98.jpg
# frame_count :100
# frame_count :101
# frame_count :102
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/99.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/100.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/101.jpg
# frame_count :103
# frame_count :104
# frame_count :105
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/102.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/103.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/104.jpg
# frame_count :106
# frame_count :107
# frame_count :108
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/105.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/106.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/107.jpg
# frame_count :109
# frame_count :110
# frame_count :111
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/108.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/109.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/110.jpg
# frame_count :112
# frame_count :113
# frame_count :114
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/111.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/112.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/113.jpg
# frame_count :115
# frame_count :116
# frame_count :117
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/114.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/115.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/116.jpg
# frame_count :118
# frame_count :119
# frame_count :120
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/117.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/118.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/119.jpg
# frame_count :121
# frame_count :122
# frame_count :123
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/120.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/121.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/122.jpg
# frame_count :124
# frame_count :125
# frame_count :126
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/123.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/124.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/125.jpg
# frame_count :127
# frame_count :128
# frame_count :129
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/126.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/127.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/128.jpg
# frame_count :130
# frame_count :131
# frame_count :132
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/129.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/130.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/131.jpg
# frame_count :133
# frame_count :134
# frame_count :135
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/132.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/133.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/134.jpg
# frame_count :136
# frame_count :137
# frame_count :138
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/135.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/136.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/137.jpg
# frame_count :139
# frame_count :140
# frame_count :141
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/138.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/139.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/140.jpg
# frame_count :142
# frame_count :143
# frame_count :144
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/141.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/142.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/143.jpg
# frame_count :145
# frame_count :146
# frame_count :147
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/144.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/145.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/146.jpg
# frame_count :148
# frame_count :149
# frame_count :150
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/147.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/148.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/149.jpg
# frame_count :151
# frame_count :152
# frame_count :153
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/150.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/151.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/152.jpg
# frame_count :154
# frame_count :155
# frame_count :156
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/153.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/154.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/155.jpg
# frame_count :157
# frame_count :158
# frame_count :159
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/156.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/157.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/158.jpg
# frame_count :160
# frame_count :161
# frame_count :162
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/159.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/160.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/161.jpg
# frame_count :163
# frame_count :164
# frame_count :165
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/162.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/163.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/164.jpg
# frame_count :166
# frame_count :167
# frame_count :168
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/165.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/166.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/167.jpg
# frame_count :169
# frame_count :170
# frame_count :171
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/168.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/169.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/170.jpg
# frame_count :172
# frame_count :173
# frame_count :174
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/171.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/172.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/173.jpg
# frame_count :175
# frame_count :176
# frame_count :177
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/174.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/175.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/176.jpg
# frame_count :178
# frame_count :179
# frame_count :180
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/177.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/178.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/179.jpg
# frame_count :181
# frame_count :182
# frame_count :183
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/180.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/181.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/182.jpg
# frame_count :184
# frame_count :185
# frame_count :186
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/183.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/184.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/185.jpg
# frame_count :187
# frame_count :188
# frame_count :189
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/186.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/187.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/188.jpg
# frame_count :190
# frame_count :191
# frame_count :192
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/189.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/190.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/191.jpg
# frame_count :193
# frame_count :194
# frame_count :195
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/192.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/193.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/194.jpg
# frame_count :196
# frame_count :197
# frame_count :198
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/195.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/196.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/197.jpg
# frame_count :199
# frame_count :200
# frame_count :201
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/198.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/199.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/200.jpg
# frame_count :202
# frame_count :203
# frame_count :204
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/201.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/202.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/203.jpg
# frame_count :205
# frame_count :206
# frame_count :207
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/204.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/205.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/206.jpg
# frame_count :208
# frame_count :209
# frame_count :210
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/207.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/208.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/209.jpg
# frame_count :211
# frame_count :212
# frame_count :213
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/210.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/211.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/212.jpg
# frame_count :214
# frame_count :215
# frame_count :216
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/213.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/214.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/215.jpg
# frame_count :217
# frame_count :218
# frame_count :219
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/216.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/217.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/218.jpg
# frame_count :220
# frame_count :221
# frame_count :222
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/219.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/220.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/221.jpg
# frame_count :223
# frame_count :224
# frame_count :225
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/222.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/223.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/224.jpg
# frame_count :226
# frame_count :227
# frame_count :228
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/225.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/226.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/227.jpg
# frame_count :229
# frame_count :230
# frame_count :231
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/228.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/229.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/230.jpg
# frame_count :232
# frame_count :233
# frame_count :234
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/231.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/232.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/233.jpg
# frame_count :235
# frame_count :236
# frame_count :237
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/234.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/235.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/236.jpg
# frame_count :238
# frame_count :239
# frame_count :240
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/237.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/238.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/239.jpg
# frame_count :241
# frame_count :242
# frame_count :243
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/240.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/241.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/242.jpg
# frame_count :244
# frame_count :245
# frame_count :246
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/243.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/244.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/245.jpg
# frame_count :247
# frame_count :248
# frame_count :249
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/246.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/247.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/248.jpg
# frame_count :250
# frame_count :251
# frame_count :252
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/249.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/250.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/251.jpg
# frame_count :253
# frame_count :254
# frame_count :255
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/252.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/253.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/254.jpg
# frame_count :256
# frame_count :257
# frame_count :258
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/255.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/256.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/257.jpg
# frame_count :259
# frame_count :260
# frame_count :261
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/258.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/259.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/260.jpg
# frame_count :262
# frame_count :263
# frame_count :264
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/261.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/262.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/263.jpg
# frame_count :265
# frame_count :266
# frame_count :267
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/264.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/265.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/266.jpg
# frame_count :268
# frame_count :269
# frame_count :270
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/267.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/268.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/269.jpg
# frame_count :271
# frame_count :272
# frame_count :273
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/270.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/271.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/272.jpg
# frame_count :274
# frame_count :275
# frame_count :276
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/273.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/274.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/275.jpg
# frame_count :277
# frame_count :278
# frame_count :279
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/276.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/277.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/278.jpg
# frame_count :280
# frame_count :281
# frame_count :282
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/279.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/280.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/281.jpg
# frame_count :283
# frame_count :284
# frame_count :285
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/282.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/283.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/284.jpg
# frame_count :286
# frame_count :287
# frame_count :288
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/285.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/286.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/287.jpg
# frame_count :289
# frame_count :290
# frame_count :291
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/288.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/289.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/290.jpg
# frame_count :292
# frame_count :293
# frame_count :294
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/291.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/292.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/293.jpg
# frame_count :295
# frame_count :296
# frame_count :297
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/294.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/295.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/296.jpg
# frame_count :298
# frame_count :299
# frame_count :300
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/297.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/298.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/299.jpg
# frame_count :301
# frame_count :302
# frame_count :303
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/300.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/301.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/302.jpg
# frame_count :304
# frame_count :305
# frame_count :306
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/303.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/304.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/305.jpg
# frame_count :307
# frame_count :308
# frame_count :309
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/306.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/307.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/308.jpg
# frame_count :310
# frame_count :311
# frame_count :312
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/309.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/310.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/311.jpg
# frame_count :313
# frame_count :314
# frame_count :315
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/312.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/313.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/314.jpg
# frame_count :316
# frame_count :317
# frame_count :318
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/315.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/316.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/317.jpg
# frame_count :319
# frame_count :320
# frame_count :321
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/318.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/319.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/320.jpg
# frame_count :322
# frame_count :323
# frame_count :324
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/321.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/322.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/323.jpg
# frame_count :325
# frame_count :326
# frame_count :327
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/324.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/325.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/326.jpg
# frame_count :328
# frame_count :329
# frame_count :330
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/327.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/328.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/329.jpg
# frame_count :331
# frame_count :332
# frame_count :333
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/330.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/331.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/332.jpg
# frame_count :334
# frame_count :335
# frame_count :336
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/333.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/334.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/335.jpg
# frame_count :337
# frame_count :338
# frame_count :339
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/336.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/337.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/338.jpg
# frame_count :340
# frame_count :341
# frame_count :342
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/339.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/340.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/341.jpg
# frame_count :343
# frame_count :344
# frame_count :345
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/342.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/343.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/344.jpg
# frame_count :346
# frame_count :347
# frame_count :348
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/345.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/346.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/347.jpg
# frame_count :349
# frame_count :350
# frame_count :351
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/348.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/349.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/350.jpg
# frame_count :352
# frame_count :353
# frame_count :354
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/351.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/352.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/353.jpg
# frame_count :355
# frame_count :356
# frame_count :357
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/354.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/355.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/356.jpg
# frame_count :358
# frame_count :359
# frame_count :360
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/357.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/358.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/359.jpg
# frame_count :361
# frame_count :362
# frame_count :363
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/360.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/361.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/362.jpg
# frame_count :364
# frame_count :365
# frame_count :366
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/363.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/364.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/365.jpg
# frame_count :367
# frame_count :368
# frame_count :369
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/366.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/367.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/368.jpg
# frame_count :370
# frame_count :371
# frame_count :372
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/369.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/370.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/371.jpg
# frame_count :373
# frame_count :374
# frame_count :375
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/372.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/373.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/374.jpg
# frame_count :376
# frame_count :377
# frame_count :378
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/375.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/376.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/377.jpg
# frame_count :379
# frame_count :380
# frame_count :381
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/378.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/379.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/380.jpg
# frame_count :382
# frame_count :383
# frame_count :384
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/381.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/382.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/383.jpg
# frame_count :385
# frame_count :386
# frame_count :387
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/384.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/385.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/386.jpg
# frame_count :388
# frame_count :389
# frame_count :390
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/387.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/388.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/389.jpg
# frame_count :391
# frame_count :392
# frame_count :393
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/390.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/391.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/392.jpg
# frame_count :394
# frame_count :395
# frame_count :396
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/393.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/394.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/395.jpg
# frame_count :397
# frame_count :398
# frame_count :399
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/396.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/397.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/398.jpg
# frame_count :400
# frame_count :401
# frame_count :402
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/399.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/400.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/401.jpg
# frame_count :403
# frame_count :404
# frame_count :405
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/402.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/403.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/404.jpg
# frame_count :406
# frame_count :407
# frame_count :408
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/405.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/406.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/407.jpg
# frame_count :409
# frame_count :410
# frame_count :411
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/408.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/409.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/410.jpg
# frame_count :412
# frame_count :413
# frame_count :414
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/411.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/412.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/413.jpg
# frame_count :415
# frame_count :416
# frame_count :417
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/414.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/415.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/416.jpg
# frame_count :418
# frame_count :419
# frame_count :420
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/417.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/418.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/419.jpg
# frame_count :421
# frame_count :422
# frame_count :423
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/420.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/421.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/422.jpg
# frame_count :424
# frame_count :425
# frame_count :426
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/423.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/424.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/425.jpg
# frame_count :427
# frame_count :428
# frame_count :429
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/426.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/427.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/428.jpg
# frame_count :430
# frame_count :431
# frame_count :432
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/429.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/430.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/431.jpg
# frame_count :433
# frame_count :434
# frame_count :435
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/432.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/433.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/434.jpg
# frame_count :436
# frame_count :437
# frame_count :438
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/435.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/436.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/437.jpg
# frame_count :439
# frame_count :440
# frame_count :441
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/438.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/439.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/440.jpg
# frame_count :442
# frame_count :443
# frame_count :444
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/441.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/442.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/443.jpg
# frame_count :445
# frame_count :446
# frame_count :447
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/444.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/445.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/446.jpg
# frame_count :448
# frame_count :449
# frame_count :450
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/447.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/448.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/449.jpg
# frame_count :451
# frame_count :452
# frame_count :453
# Predicted
# ...
# frame_count :3526
# frame_count :3527
# frame_count :3528
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3525.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3526.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3527.jpg
# frame_count :3529
# frame_count :3530
# frame_count :3531
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3528.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3529.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3530.jpg
# frame_count :3532
# frame_count :3533
# frame_count :3534
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3531.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3532.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3533.jpg
# frame_count :3535
# frame_count :3536
# frame_count :3537
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3534.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3535.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3536.jpg
# frame_count :3538
# frame_count :3539
# frame_count :3540
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3537.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3538.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3539.jpg
# frame_count :3541
# frame_count :3542
# frame_count :3543
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3540.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3541.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3542.jpg
# frame_count :3544
# frame_count :3545
# frame_count :3546
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3543.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3544.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3545.jpg
# frame_count :3547
# frame_count :3548
# frame_count :3549
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3546.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3547.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3548.jpg
# frame_count :3550
# frame_count :3551
# frame_count :3552
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3549.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3550.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3551.jpg
# frame_count :3553
# frame_count :3554
# frame_count :3555
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3552.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3553.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3554.jpg
# frame_count :3556
# frame_count :3557
# frame_count :3558
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3555.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3556.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3557.jpg
# frame_count :3559
# frame_count :3560
# frame_count :3561
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3558.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3559.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3560.jpg
# frame_count :3562
# frame_count :3563
# frame_count :3564
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3561.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3562.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3563.jpg
# frame_count :3565
# frame_count :3566
# frame_count :3567
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3564.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3565.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3566.jpg
# frame_count :3568
# frame_count :3569
# frame_count :3570
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3567.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3568.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3569.jpg
# frame_count :3571
# frame_count :3572
# frame_count :3573
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3570.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3571.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3572.jpg
# frame_count :3574
# frame_count :3575
# frame_count :3576
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3573.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3574.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3575.jpg
# frame_count :3577
# frame_count :3578
# frame_count :3579
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3576.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3577.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3578.jpg
# frame_count :3580
# frame_count :3581
# frame_count :3582
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3579.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3580.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3581.jpg
# frame_count :3583
# frame_count :3584
# frame_count :3585
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3582.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3583.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3584.jpg
# frame_count :3586
# frame_count :3587
# frame_count :3588
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3585.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3586.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3587.jpg
# frame_count :3589
# frame_count :3590
# frame_count :3591
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3588.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3589.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3590.jpg
# frame_count :3592
# frame_count :3593
# frame_count :3594
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3591.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3592.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3593.jpg
# frame_count :3595
# frame_count :3596
# frame_count :3597
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3594.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3595.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3596.jpg
# frame_count :3598
# frame_count :3599
# frame_count :3600
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3597.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3598.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3599.jpg
# frame_count :3601
# frame_count :3602
# frame_count :3603
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3600.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3601.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3602.jpg
# frame_count :3604
# frame_count :3605
# frame_count :3606
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3603.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3604.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3605.jpg
# frame_count :3607
# frame_count :3608
# frame_count :3609
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3606.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3607.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3608.jpg
# frame_count :3610
# frame_count :3611
# frame_count :3612
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3609.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3610.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3611.jpg
# frame_count :3613
# frame_count :3614
# frame_count :3615
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3612.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3613.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3614.jpg
# frame_count :3616
# frame_count :3617
# frame_count :3618
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3615.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3616.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3617.jpg
# frame_count :3619
# frame_count :3620
# frame_count :3621
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3618.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3619.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3620.jpg
# frame_count :3622
# frame_count :3623
# frame_count :3624
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3621.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3622.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3623.jpg
# frame_count :3625
# frame_count :3626
# frame_count :3627
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3624.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3625.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3626.jpg
# frame_count :3628
# frame_count :3629
# frame_count :3630
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3627.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3628.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3629.jpg
# frame_count :3631
# frame_count :3632
# frame_count :3633
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3630.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3631.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3632.jpg
# frame_count :3634
# frame_count :3635
# frame_count :3636
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3633.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3634.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3635.jpg
# frame_count :3637
# frame_count :3638
# frame_count :3639
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3636.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3637.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3638.jpg
# frame_count :3640
# frame_count :3641
# frame_count :3642
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3639.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3640.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3641.jpg
# frame_count :3643
# frame_count :3644
# frame_count :3645
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3642.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3643.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3644.jpg
# frame_count :3646
# frame_count :3647
# frame_count :3648
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3645.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3646.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3647.jpg
# frame_count :3649
# frame_count :3650
# frame_count :3651
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3648.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3649.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3650.jpg
# frame_count :3652
# frame_count :3653
# frame_count :3654
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3651.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3652.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3653.jpg
# frame_count :3655
# frame_count :3656
# frame_count :3657
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3654.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3655.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3656.jpg
# frame_count :3658
# frame_count :3659
# frame_count :3660
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3657.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3658.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3659.jpg
# frame_count :3661
# frame_count :3662
# frame_count :3663
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3660.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3661.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3662.jpg
# frame_count :3664
# frame_count :3665
# frame_count :3666
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3663.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3664.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3665.jpg
# frame_count :3667
# frame_count :3668
# frame_count :3669
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3666.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3667.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3668.jpg
# frame_count :3670
# frame_count :3671
# frame_count :3672
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3669.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3670.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3671.jpg
# frame_count :3673
# frame_count :3674
# frame_count :3675
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3672.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3673.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3674.jpg
# frame_count :3676
# frame_count :3677
# frame_count :3678
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3675.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3676.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3677.jpg
# frame_count :3679
# frame_count :3680
# frame_count :3681
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3678.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3679.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3680.jpg
# frame_count :3682
# frame_count :3683
# frame_count :3684
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3681.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3682.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3683.jpg
# frame_count :3685
# frame_count :3686
# frame_count :3687
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3684.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3685.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3686.jpg
# frame_count :3688
# frame_count :3689
# frame_count :3690
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3687.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3688.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3689.jpg
# frame_count :3691
# frame_count :3692
# frame_count :3693
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3690.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3691.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3692.jpg
# frame_count :3694
# frame_count :3695
# frame_count :3696
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3693.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3694.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save/3695.jpg
# frame_count :3697
# frame_count :3698

# %%
video = cv2.VideoCapture(os.path.join(VIDEO_DIR, 'data.mp4'));

# Find OpenCV version
(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')

if int(major_ver)  < 3 :
    fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(fps))
else :
    fps = video.get(cv2.CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))

video.release();
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 30.0

# %%
def make_video(outvid, images=None, fps=30, size=None,
               is_color=True, format="FMP4"):
    """
    Create a video from a list of images.
 
    @param      outvid      output video
    @param      images      list of images to use in the video
    @param      fps         frame per second
    @param      size        size of each frame
    @param      is_color    color
    By default, the video will have the size of the first image.
    It will resize every image to this size before adding them to the video.
    """
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    vid.release()
    return vid

import glob
import os

# Directory of images to run detection on
ROOT_DIR = os.getcwd()
VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "save")
images = list(glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*')))
# Sort the images by integer index
images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))

outvid = os.path.join(VIDEO_DIR, "out.mp4")
make_video(outvid, images, fps=30)
# Out:
# <VideoWriter 0x7f9e93f6d710>
