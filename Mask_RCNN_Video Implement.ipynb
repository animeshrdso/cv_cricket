# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir('./gdrive/My Drive/Mask_RCNN')

# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt

ROOT_DIR = os.path.abspath("Desktop/Mask_RCNN")
import warnings
warnings.filterwarnings("ignore")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
# Import COCO config
#sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
import cv2
import numpy as np


def random_colors(N):
    np.random.seed(1)
    colors = [tuple(255 * np.random.rand(3)) for _ in range(N)]
    return colors


def apply_mask(image, mask, color, alpha=0.5):
    """apply mask to image"""
    for n, c in enumerate(color):
        image[:, :, n] = np.where(
            mask == 1,
            image[:, :, n] * (1 - alpha) + alpha * c,
            image[:, :, n]
        )
    return image

def display_instances(image, boxes, masks, ids, names, scores):
    """
        take the image and results and apply the mask, box, and Label
    """
    n_instances = boxes.shape[0]
    colors = random_colors(n_instances)

    if not n_instances:
        print('NO INSTANCES TO DISPLAY')
    else:
        assert boxes.shape[0] == masks.shape[-1] == ids.shape[0]

    for i, color in enumerate(colors):
        if not np.any(boxes[i]):
            continue

        y1, x1, y2, x2 = boxes[i]
        label = names[ids[i]]
        if (label == 'person' or label == 'sports ball' or label == 'baseball bat'):
          score = scores[i] if scores is not None else None
          caption = '{} {:.2f}'.format(label, score) if score else label
          mask = masks[:, :, i]

          image = apply_mask(image, mask, color)
          image = cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
          image = cv2.putText(
            image, caption, (x1, y1), cv2.FONT_HERSHEY_COMPLEX, 0.7, color, 2
          )
        
    return image

if __name__ == '__main__':
    """
        test everything
    """
    import os
    import sys
    from mrcnn import utils
    import mrcnn.model as modellib
    #sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
    from samples.coco import coco
    
    # We use a K80 GPU with 24GB memory, which can fit 3 images.
    batch_size = 3

    ROOT_DIR = os.getcwd()
    MODEL_DIR = os.path.join(ROOT_DIR, "logs")
    VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
    VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "save2")
    COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
    if not os.path.exists(COCO_MODEL_PATH):
        utils.download_trained_weights(COCO_MODEL_PATH)
        
    class InferenceConfig(coco.CocoConfig):
        GPU_COUNT = 1
        IMAGES_PER_GPU = batch_size

    config = InferenceConfig()
    config.display()

    model = modellib.MaskRCNN(
        mode="inference", model_dir=MODEL_DIR, config=config
    )
    model.load_weights(COCO_MODEL_PATH, by_name=True)
    class_names = [
        'BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
        'bus', 'train', 'truck', 'boat', 'traffic light',
        'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
        'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
        'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
        'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
        'kite', 'baseball bat', 'baseball glove', 'skateboard',
        'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
        'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
        'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
        'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
        'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
        'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
        'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
        'teddy bear', 'hair drier', 'toothbrush'
    ]
    
    capture = cv2.VideoCapture(os.path.join(VIDEO_DIR, 'video_crop.mp4'))
    try:
        if not os.path.exists(VIDEO_SAVE_DIR):
            os.makedirs(VIDEO_SAVE_DIR)
    except OSError:
        print ('Error: Creating directory of data')
    frames = []
    frame_count = 0
    # these 2 lines can be removed if you dont have a 1080p camera.
    #capture.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
    #capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)

    while True:
        ret, frame = capture.read()
        # Bail out when the video file ends
        if not ret:
            break
        
        # Save each frame of the video to a list
        frame_count += 1
        frames.append(frame)
        print('frame_count :{0}'.format(frame_count))
        if len(frames) == batch_size:
            results = model.detect(frames, verbose=0)
            print('Predicted')
            for i, item in enumerate(zip(frames, results)):
                frame = item[0]
                r = item[1]
                frame = display_instances(
                    frame, r['rois'], r['masks'], r['class_ids'], class_names, r['scores']
                )
                name = '{0}.jpg'.format(frame_count + i - batch_size)
                name = os.path.join(VIDEO_SAVE_DIR, name)
                cv2.imwrite(name, frame)
                print('writing to file:{0}'.format(name))
            # Clear the frames array to start the next batch
            frames = []

    capture.release()
# Out:
# Streaming output truncated to the last 5000 lines.
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2536.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2537.jpg
# frame_count :2539
# frame_count :2540
# frame_count :2541
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2538.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2539.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2540.jpg
# frame_count :2542
# frame_count :2543
# frame_count :2544
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2541.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2542.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2543.jpg
# frame_count :2545
# frame_count :2546
# frame_count :2547
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2544.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2545.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2546.jpg
# frame_count :2548
# frame_count :2549
# frame_count :2550
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2547.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2548.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2549.jpg
# frame_count :2551
# frame_count :2552
# frame_count :2553
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2550.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2551.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2552.jpg
# frame_count :2554
# frame_count :2555
# frame_count :2556
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2553.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2554.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2555.jpg
# frame_count :2557
# frame_count :2558
# frame_count :2559
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2556.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2557.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2558.jpg
# frame_count :2560
# frame_count :2561
# frame_count :2562
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2559.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2560.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2561.jpg
# frame_count :2563
# frame_count :2564
# frame_count :2565
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2562.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2563.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2564.jpg
# frame_count :2566
# frame_count :2567
# frame_count :2568
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2565.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2566.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2567.jpg
# frame_count :2569
# frame_count :2570
# frame_count :2571
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2568.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2569.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2570.jpg
# frame_count :2572
# frame_count :2573
# frame_count :2574
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2571.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2572.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2573.jpg
# frame_count :2575
# frame_count :2576
# frame_count :2577
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2574.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2575.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2576.jpg
# frame_count :2578
# frame_count :2579
# frame_count :2580
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2577.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2578.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2579.jpg
# frame_count :2581
# frame_count :2582
# frame_count :2583
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2580.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2581.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2582.jpg
# frame_count :2584
# frame_count :2585
# frame_count :2586
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2583.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2584.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2585.jpg
# frame_count :2587
# frame_count :2588
# frame_count :2589
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2586.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2587.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2588.jpg
# frame_count :2590
# frame_count :2591
# frame_count :2592
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2589.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2590.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2591.jpg
# frame_count :2593
# frame_count :2594
# frame_count :2595
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2592.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2593.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2594.jpg
# frame_count :2596
# frame_count :2597
# frame_count :2598
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2595.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2596.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2597.jpg
# frame_count :2599
# frame_count :2600
# frame_count :2601
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2598.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2599.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2600.jpg
# frame_count :2602
# frame_count :2603
# frame_count :2604
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2601.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2602.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2603.jpg
# frame_count :2605
# frame_count :2606
# frame_count :2607
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2604.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2605.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2606.jpg
# frame_count :2608
# frame_count :2609
# frame_count :2610
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2607.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2608.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2609.jpg
# frame_count :2611
# frame_count :2612
# frame_count :2613
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2610.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2611.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2612.jpg
# frame_count :2614
# frame_count :2615
# frame_count :2616
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2613.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2614.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2615.jpg
# frame_count :2617
# frame_count :2618
# frame_count :2619
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2616.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2617.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2618.jpg
# frame_count :2620
# frame_count :2621
# frame_count :2622
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2619.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2620.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2621.jpg
# frame_count :2623
# frame_count :2624
# frame_count :2625
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2622.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2623.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2624.jpg
# frame_count :2626
# frame_count :2627
# frame_count :2628
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2625.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2626.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2627.jpg
# frame_count :2629
# frame_count :2630
# frame_count :2631
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2628.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2629.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2630.jpg
# frame_count :2632
# frame_count :2633
# frame_count :2634
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2631.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2632.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2633.jpg
# frame_count :2635
# frame_count :2636
# frame_count :2637
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2634.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2635.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2636.jpg
# frame_count :2638
# frame_count :2639
# frame_count :2640
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2637.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2638.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2639.jpg
# frame_count :2641
# frame_count :2642
# frame_count :2643
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2640.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2641.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2642.jpg
# frame_count :2644
# frame_count :2645
# frame_count :2646
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2643.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2644.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2645.jpg
# frame_count :2647
# frame_count :2648
# frame_count :2649
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2646.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2647.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2648.jpg
# frame_count :2650
# frame_count :2651
# frame_count :2652
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2649.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2650.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2651.jpg
# frame_count :2653
# frame_count :2654
# frame_count :2655
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2652.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2653.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2654.jpg
# frame_count :2656
# frame_count :2657
# frame_count :2658
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2655.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2656.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2657.jpg
# frame_count :2659
# frame_count :2660
# frame_count :2661
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2658.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2659.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2660.jpg
# frame_count :2662
# frame_count :2663
# frame_count :2664
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2661.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2662.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2663.jpg
# frame_count :2665
# frame_count :2666
# frame_count :2667
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2664.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2665.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2666.jpg
# frame_count :2668
# frame_count :2669
# frame_count :2670
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2667.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2668.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2669.jpg
# frame_count :2671
# frame_count :2672
# frame_count :2673
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2670.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2671.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2672.jpg
# frame_count :2674
# frame_count :2675
# frame_count :2676
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2673.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2674.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2675.jpg
# frame_count :2677
# frame_count :2678
# frame_count :2679
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2676.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2677.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2678.jpg
# frame_count :2680
# frame_count :2681
# frame_count :2682
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2679.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2680.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2681.jpg
# frame_count :2683
# frame_count :2684
# frame_count :2685
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2682.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2683.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2684.jpg
# frame_count :2686
# frame_count :2687
# frame_count :2688
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2685.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2686.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2687.jpg
# frame_count :2689
# frame_count :2690
# frame_count :2691
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2688.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2689.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2690.jpg
# frame_count :2692
# frame_count :2693
# frame_count :2694
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2691.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2692.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2693.jpg
# frame_count :2695
# frame_count :2696
# frame_count :2697
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2694.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2695.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2696.jpg
# frame_count :2698
# frame_count :2699
# frame_count :2700
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2697.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2698.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2699.jpg
# frame_count :2701
# frame_count :2702
# frame_count :2703
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2700.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2701.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2702.jpg
# frame_count :2704
# frame_count :2705
# frame_count :2706
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2703.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2704.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2705.jpg
# frame_count :2707
# frame_count :2708
# frame_count :2709
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2706.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2707.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2708.jpg
# frame_count :2710
# frame_count :2711
# frame_count :2712
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2709.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2710.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2711.jpg
# frame_count :2713
# frame_count :2714
# frame_count :2715
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2712.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2713.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2714.jpg
# frame_count :2716
# frame_count :2717
# frame_count :2718
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2715.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2716.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2717.jpg
# frame_count :2719
# frame_count :2720
# frame_count :2721
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2718.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2719.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2720.jpg
# frame_count :2722
# frame_count :2723
# frame_count :2724
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2721.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2722.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2723.jpg
# frame_count :2725
# frame_count :2726
# frame_count :2727
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2724.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2725.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2726.jpg
# frame_count :2728
# frame_count :2729
# frame_count :2730
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2727.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2728.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2729.jpg
# frame_count :2731
# frame_count :2732
# frame_count :2733
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2730.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2731.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2732.jpg
# frame_count :2734
# frame_count :2735
# frame_count :2736
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2733.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2734.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2735.jpg
# frame_count :2737
# frame_count :2738
# frame_count :2739
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2736.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2737.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2738.jpg
# frame_count :2740
# frame_count :2741
# frame_count :2742
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2739.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2740.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2741.jpg
# frame_count :2743
# frame_count :2744
# frame_count :2745
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2742.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2743.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2744.jpg
# frame_count :2746
# frame_count :2747
# frame_count :2748
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2745.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2746.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2747.jpg
# frame_count :2749
# frame_count :2750
# frame_count :2751
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2748.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2749.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2750.jpg
# frame_count :2752
# frame_count :2753
# frame_count :2754
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2751.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2752.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2753.jpg
# frame_count :2755
# frame_count :2756
# frame_count :2757
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2754.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2755.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2756.jpg
# frame_count :2758
# frame_count :2759
# frame_count :2760
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2757.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2758.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2759.jpg
# frame_count :2761
# frame_count :2762
# frame_count :2763
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2760.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2761.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2762.jpg
# frame_count :2764
# frame_count :2765
# frame_count :2766
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2763.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2764.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2765.jpg
# frame_count :2767
# frame_count :2768
# frame_count :2769
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2766.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2767.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2768.jpg
# frame_count :2770
# frame_count :2771
# frame_count :2772
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2769.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2770.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2771.jpg
# frame_count :2773
# frame_count :2774
# frame_count :2775
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2772.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2773.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2774.jpg
# frame_count :2776
# frame_count :2777
# frame_count :2778
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2775.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2776.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2777.jpg
# frame_count :2779
# frame_count :2780
# frame_count :2781
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2778.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2779.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2780.jpg
# frame_count :2782
# frame_count :2783
# frame_count :2784
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2781.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2782.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2783.jpg
# frame_count :2785
# frame_count :2786
# frame_count :2787
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2784.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2785.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2786.jpg
# frame_count :2788
# frame_count :2789
# frame_count :2790
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2787.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2788.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2789.jpg
# frame_count :2791
# frame_count :2792
# frame_count :2793
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2790.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2791.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2792.jpg
# frame_count :2794
# frame_count :2795
# frame_count :2796
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2793.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2794.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2795.jpg
# frame_count :2797
# frame_count :2798
# frame_count :2799
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2796.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2797.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2798.jpg
# frame_count :2800
# frame_count :2801
# frame_count :2802
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2799.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2800.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2801.jpg
# frame_count :2803
# frame_count :2804
# frame_count :2805
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2802.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2803.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2804.jpg
# frame_count :2806
# frame_count :2807
# frame_count :2808
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2805.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2806.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2807.jpg
# frame_count :2809
# frame_count :2810
# frame_count :2811
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2808.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2809.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2810.jpg
# frame_count :2812
# frame_count :2813
# frame_count :2814
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2811.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2812.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2813.jpg
# frame_count :2815
# frame_count :2816
# frame_count :2817
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2814.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2815.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2816.jpg
# frame_count :2818
# frame_count :2819
# frame_count :2820
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2817.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2818.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2819.jpg
# frame_count :2821
# frame_count :2822
# frame_count :2823
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2820.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2821.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2822.jpg
# frame_count :2824
# frame_count :2825
# frame_count :2826
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2823.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2824.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2825.jpg
# frame_count :2827
# frame_count :2828
# frame_count :2829
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2826.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2827.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2828.jpg
# frame_count :2830
# frame_count :2831
# frame_count :2832
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2829.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2830.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2831.jpg
# frame_count :2833
# frame_count :2834
# frame_count :2835
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2832.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2833.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2834.jpg
# frame_count :2836
# frame_count :2837
# frame_count :2838
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2835.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2836.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2837.jpg
# frame_count :2839
# frame_count :2840
# frame_count :2841
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2838.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2839.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2840.jpg
# frame_count :2842
# frame_count :2843
# frame_count :2844
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2841.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2842.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2843.jpg
# frame_count :2845
# frame_count :2846
# frame_count :2847
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2844.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2845.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2846.jpg
# frame_count :2848
# frame_count :2849
# frame_count :2850
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2847.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2848.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2849.jpg
# frame_count :2851
# frame_count :2852
# frame_count :2853
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2850.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2851.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2852.jpg
# frame_count :2854
# frame_count :2855
# frame_count :2856
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2853.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2854.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2855.jpg
# frame_count :2857
# frame_count :2858
# frame_count :2859
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2856.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2857.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2858.jpg
# frame_count :2860
# frame_count :2861
# frame_count :2862
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2859.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2860.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2861.jpg
# frame_count :2863
# frame_count :2864
# frame_count :2865
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2862.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2863.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2864.jpg
# frame_count :2866
# frame_count :2867
# frame_count :2868
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2865.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2866.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2867.jpg
# frame_count :2869
# frame_count :2870
# frame_count :2871
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2868.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2869.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2870.jpg
# frame_count :2872
# frame_count :2873
# frame_count :2874
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2871.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2872.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2873.jpg
# frame_count :2875
# frame_count :2876
# frame_count :2877
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2874.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2875.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2876.jpg
# frame_count :2878
# frame_count :2879
# frame_count :2880
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2877.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2878.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2879.jpg
# frame_count :2881
# frame_count :2882
# frame_count :2883
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2880.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2881.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2882.jpg
# frame_count :2884
# frame_count :2885
# frame_count :2886
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2883.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2884.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2885.jpg
# frame_count :2887
# frame_count :2888
# frame_count :2889
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2886.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2887.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2888.jpg
# frame_count :2890
# frame_count :2891
# frame_count :2892
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2889.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2890.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2891.jpg
# frame_count :2893
# frame_count :2894
# frame_count :2895
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2892.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2893.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2894.jpg
# frame_count :2896
# frame_count :2897
# frame_count :2898
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2895.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2896.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2897.jpg
# frame_count :2899
# frame_count :2900
# frame_count :2901
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2898.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2899.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2900.jpg
# frame_count :2902
# frame_count :2903
# frame_count :2904
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2901.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2902.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2903.jpg
# frame_count :2905
# frame_count :2906
# frame_count :2907
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2904.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2905.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2906.jpg
# frame_count :2908
# frame_count :2909
# frame_count :2910
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2907.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2908.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2909.jpg
# frame_count :2911
# frame_count :2912
# frame_count :2913
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2910.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2911.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2912.jpg
# frame_count :2914
# frame_count :2915
# frame_count :2916
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2913.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2914.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2915.jpg
# frame_count :2917
# frame_count :2918
# frame_count :2919
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2916.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2917.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2918.jpg
# frame_count :2920
# frame_count :2921
# frame_count :2922
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2919.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2920.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2921.jpg
# frame_count :2923
# frame_count :2924
# frame_count :2925
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2922.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2923.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2924.jpg
# frame_count :2926
# frame_count :2927
# frame_count :2928
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2925.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2926.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2927.jpg
# frame_count :2929
# frame_count :2930
# frame_count :2931
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2928.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2929.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2930.jpg
# frame_count :2932
# frame_count :2933
# frame_count :2934
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2931.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2932.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2933.jpg
# frame_count :2935
# frame_count :2936
# frame_count :2937
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2934.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2935.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2936.jpg
# frame_count :2938
# frame_count :2939
# frame_count :2940
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2937.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2938.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2939.jpg
# frame_count :2941
# frame_count :2942
# frame_count :2943
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2940.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2941.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2942.jpg
# frame_count :2944
# frame_count :2945
# frame_count :2946
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2943.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2944.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2945.jpg
# frame_count :2947
# frame_count :2948
# frame_count :2949
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2946.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2947.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2948.jpg
# frame_count :2950
# frame_count :2951
# frame_count :2952
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2949.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2950.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2951.jpg
# frame_count :2953
# frame_count :2954
# frame_count :2955
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2952.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2953.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2954.jpg
# frame_count :2956
# frame_count :2957
# frame_count :2958
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2955.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2956.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2957.jpg
# frame_count :2959
# frame_count :2960
# frame_count :2961
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2958.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2959.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2960.jpg
# frame_count :2962
# frame_count :2963
# frame_count :2964
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2961.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2962.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2963.jpg
# frame_count :2965
# frame_count :2966
# frame_count :2967
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2964.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2965.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2966.jpg
# frame_count :2968
# frame_count :2969
# frame_count :2970
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2967.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2968.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2969.jpg
# frame_count :2971
# frame_count :2972
# frame_count :2973
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2970.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2971.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2972.jpg
# frame_count :2974
# frame_count :2975
# frame_count :2976
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2973.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2974.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2975.jpg
# frame_count :2977
# frame_count :2978
# frame_count :2979
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2976.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2977.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2978.jpg
# frame_count :2980
# frame_count :2981
# frame_count :2982
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2979.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2980.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2981.jpg
# frame_count :2983
# frame_count :2984
# frame_count :2985
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2982.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2983.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2984.jpg
# frame_count :2986
# frame_count :2987
# frame_count :2988
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2985.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2986.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2987.jpg
# frame_count :2989
# frame_count :2990
# frame_count :2991
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2988.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2989.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2990.jpg
# frame_count :2992
# frame_count :2993
# frame_count :2994
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2991.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2992.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2993.jpg
# frame_count :2995
# frame_count :2996
# frame_count :2997
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2994.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2995.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2996.jpg
# frame_count :2998
# frame_count :2999
# frame_count :3000
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2997.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2998.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/2999.jpg
# frame_count :3001
# frame_count :3002
# frame_count :3003
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3000.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3001.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3002.jpg
# frame_count :3004
# frame_count :3005
# frame_count :3006
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3003.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3004.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3005.jpg
# frame_count :3007
# frame_count :3008
# frame_count :3009
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3006.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3007.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3008.jpg
# frame_count :3010
# frame_count :3011
# frame_count :3012
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3009.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3010.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3011.jpg
# frame_count :3013
# frame_count :3014
# frame_count :3015
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3012.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3013.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3014.jpg
# frame_count :3016
# frame_count :3017
# frame_count :3018
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3015.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3016.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3017.jpg
# frame_count :3019
# frame_count :3020
# frame_count :3021
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3018.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3019.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3020.jpg
# frame_count :3022
# frame_count :3023
# frame_count :3024
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3021.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3022.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3023.jpg
# frame_count :3025
# frame_count :3026
# frame_count :3027
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3024.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3025.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3026.jpg
# frame_count :3028
# frame_count :3029
# frame_count :3030
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3027.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3028.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3029.jpg
# frame_count :3031
# frame_count :3032
# frame_count :3033
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3030.jpg
# NO INSTANCES TO DISPLAY
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/3031.jpg
# ...
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4454.jpg
# frame_count :4456
# frame_count :4457
# frame_count :4458
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4455.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4456.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4457.jpg
# frame_count :4459
# frame_count :4460
# frame_count :4461
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4458.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4459.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4460.jpg
# frame_count :4462
# frame_count :4463
# frame_count :4464
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4461.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4462.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4463.jpg
# frame_count :4465
# frame_count :4466
# frame_count :4467
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4464.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4465.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4466.jpg
# frame_count :4468
# frame_count :4469
# frame_count :4470
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4467.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4468.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4469.jpg
# frame_count :4471
# frame_count :4472
# frame_count :4473
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4470.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4471.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4472.jpg
# frame_count :4474
# frame_count :4475
# frame_count :4476
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4473.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4474.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4475.jpg
# frame_count :4477
# frame_count :4478
# frame_count :4479
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4476.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4477.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4478.jpg
# frame_count :4480
# frame_count :4481
# frame_count :4482
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4479.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4480.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4481.jpg
# frame_count :4483
# frame_count :4484
# frame_count :4485
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4482.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4483.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4484.jpg
# frame_count :4486
# frame_count :4487
# frame_count :4488
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4485.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4486.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4487.jpg
# frame_count :4489
# frame_count :4490
# frame_count :4491
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4488.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4489.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4490.jpg
# frame_count :4492
# frame_count :4493
# frame_count :4494
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4491.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4492.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4493.jpg
# frame_count :4495
# frame_count :4496
# frame_count :4497
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4494.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4495.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4496.jpg
# frame_count :4498
# frame_count :4499
# frame_count :4500
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4497.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4498.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4499.jpg
# frame_count :4501
# frame_count :4502
# frame_count :4503
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4500.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4501.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4502.jpg
# frame_count :4504
# frame_count :4505
# frame_count :4506
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4503.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4504.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4505.jpg
# frame_count :4507
# frame_count :4508
# frame_count :4509
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4506.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4507.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4508.jpg
# frame_count :4510
# frame_count :4511
# frame_count :4512
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4509.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4510.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4511.jpg
# frame_count :4513
# frame_count :4514
# frame_count :4515
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4512.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4513.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4514.jpg
# frame_count :4516
# frame_count :4517
# frame_count :4518
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4515.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4516.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4517.jpg
# frame_count :4519
# frame_count :4520
# frame_count :4521
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4518.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4519.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4520.jpg
# frame_count :4522
# frame_count :4523
# frame_count :4524
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4521.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4522.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4523.jpg
# frame_count :4525
# frame_count :4526
# frame_count :4527
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4524.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4525.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4526.jpg
# frame_count :4528
# frame_count :4529
# frame_count :4530
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4527.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4528.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4529.jpg
# frame_count :4531
# frame_count :4532
# frame_count :4533
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4530.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4531.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4532.jpg
# frame_count :4534
# frame_count :4535
# frame_count :4536
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4533.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4534.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4535.jpg
# frame_count :4537
# frame_count :4538
# frame_count :4539
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4536.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4537.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4538.jpg
# frame_count :4540
# frame_count :4541
# frame_count :4542
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4539.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4540.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4541.jpg
# frame_count :4543
# frame_count :4544
# frame_count :4545
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4542.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4543.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4544.jpg
# frame_count :4546
# frame_count :4547
# frame_count :4548
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4545.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4546.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4547.jpg
# frame_count :4549
# frame_count :4550
# frame_count :4551
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4548.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4549.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4550.jpg
# frame_count :4552
# frame_count :4553
# frame_count :4554
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4551.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4552.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4553.jpg
# frame_count :4555
# frame_count :4556
# frame_count :4557
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4554.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4555.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4556.jpg
# frame_count :4558
# frame_count :4559
# frame_count :4560
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4557.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4558.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4559.jpg
# frame_count :4561
# frame_count :4562
# frame_count :4563
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4560.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4561.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4562.jpg
# frame_count :4564
# frame_count :4565
# frame_count :4566
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4563.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4564.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4565.jpg
# frame_count :4567
# frame_count :4568
# frame_count :4569
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4566.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4567.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4568.jpg
# frame_count :4570
# frame_count :4571
# frame_count :4572
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4569.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4570.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4571.jpg
# frame_count :4573
# frame_count :4574
# frame_count :4575
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4572.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4573.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4574.jpg
# frame_count :4576
# frame_count :4577
# frame_count :4578
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4575.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4576.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4577.jpg
# frame_count :4579
# frame_count :4580
# frame_count :4581
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4578.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4579.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4580.jpg
# frame_count :4582
# frame_count :4583
# frame_count :4584
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4581.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4582.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4583.jpg
# frame_count :4585
# frame_count :4586
# frame_count :4587
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4584.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4585.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4586.jpg
# frame_count :4588
# frame_count :4589
# frame_count :4590
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4587.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4588.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4589.jpg
# frame_count :4591
# frame_count :4592
# frame_count :4593
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4590.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4591.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4592.jpg
# frame_count :4594
# frame_count :4595
# frame_count :4596
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4593.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4594.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4595.jpg
# frame_count :4597
# frame_count :4598
# frame_count :4599
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4596.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4597.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4598.jpg
# frame_count :4600
# frame_count :4601
# frame_count :4602
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4599.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4600.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4601.jpg
# frame_count :4603
# frame_count :4604
# frame_count :4605
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4602.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4603.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4604.jpg
# frame_count :4606
# frame_count :4607
# frame_count :4608
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4605.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4606.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4607.jpg
# frame_count :4609
# frame_count :4610
# frame_count :4611
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4608.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4609.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4610.jpg
# frame_count :4612
# frame_count :4613
# frame_count :4614
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4611.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4612.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4613.jpg
# frame_count :4615
# frame_count :4616
# frame_count :4617
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4614.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4615.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4616.jpg
# frame_count :4618
# frame_count :4619
# frame_count :4620
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4617.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4618.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4619.jpg
# frame_count :4621
# frame_count :4622
# frame_count :4623
# Predicted
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4620.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4621.jpg
# writing to file:/content/gdrive/My Drive/Mask_RCNN/videos/save2/4622.jpg
# frame_count :4624

# %%
video = cv2.VideoCapture(os.path.join(VIDEO_DIR, 'video_crop.mp4'));

# Find OpenCV version
(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')

if int(major_ver)  < 3 :
    fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(fps))
else :
    fps = video.get(cv2.CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))

video.release();
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 25.0

# %%
def make_video(outvid, images=None, fps=25, size=None,
               is_color=True, format="FMP4"):
    """
    Create a video from a list of images.
 
    @param      outvid      output video
    @param      images      list of images to use in the video
    @param      fps         frame per second
    @param      size        size of each frame
    @param      is_color    color
    @param      format      see http://www.fourcc.org/codecs.php
    @return                 see http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_gui/py_video_display/py_video_display.html
 
    The function relies on http://opencv-python-tutroals.readthedocs.org/en/latest/.
    By default, the video will have the size of the first image.
    It will resize every image to this size before adding them to the video.
    """
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    vid.release()
    return vid

import glob
import os

# Directory of images to run detection on
ROOT_DIR = os.getcwd()
VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "save2")
images = list(glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*')))
# Sort the images by integer index
images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))

outvid = os.path.join(VIDEO_DIR, "video_out.mp4")
make_video(outvid, images, fps=25)
# Out:
# <VideoWriter 0x7fa73799a090>

# %%
from google.colab import files
files.download('videos/video_out.mp4')
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 52738, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 320, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 351, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 364, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 724, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 803, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
